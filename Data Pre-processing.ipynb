# %% [markdown]
# # Read the train_data.json file from the link https://www.hackerearth.com/problem/machine-learning/predict-the-segment-hotstar/ and converted it into dataframe

# %%
import json 
import csv
import pandas as pd

# %%
with open('train_data.json') as hotstar:
    data = json.load(hotstar)

# %%
data
# Out:
# {'train-121672': {'genres': 'Drama:6,Cricket:3469,Wildlife:79',
#   'titles': 'Wild Sex:79,Vintage Dhoni Comes Good with 134:320,India vs England | 2nd ODI | English:2922,MS Dhoni: The Untold Story:6,Dhoni Does It the Mahi Way with 134:41,Six! Kohli Gets to Century in Style:0,India vs England 3rd ODI English:64,2017: Kohli Leads the Way with 122:38,2011: Yuvi Dethrones Oz in WC QF:83',
#   'cities': 'delhi:3492,mumbai:64',
#   'segment': 'neg',
#   'dow': '5:482,4:3008,7:64',
#   'tod': '18:1372,21:1862,17:320'},
#  'train-121673': {'genres': 'Drama:48949,Family:9927,Crime:1901,Romance:16571,Action:2064,Comedy:4225',
# ...

# %%
train = pd.DataFrame.from_dict(data, orient='index')

# %%
train.reset_index(level=0, inplace=True)
train.rename(columns = {'index':'ID'},inplace=True)
train.shape
# Out:
# (200000, 7)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       200000 non-null  object
#  1   genres   200000 non-null  object
#  2   titles   200000 non-null  object
#  3   cities   200000 non-null  object
#  4   segment  200000 non-null  object
#  5   dow      200000 non-null  object
#  6   tod      200000 non-null  object
# dtypes: object(7)
# memory usage: 10.7+ MB

# %%
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 199995  train-126324                            Cricket:3787,Reality:57
# 199996  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 199997  train-126326                               Drama:25428,Family:7
# 199998  train-126329                              Drama:50749,Romance:9
# 199999  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train.ID.nunique()
# Out:
# 200000

# %%
train.to_csv("train_1.csv")

# %% [markdown]
# # After manually verifying and removing the rows which were not in proper format (string:value), train1.csv created and further rows were deleted which had null values or improper data. Finally new columns were generated from this dataframe

# %% [markdown]
# # Columns such as prime_time, prime_day, no_pgm_watched, no_place_presence, most_watched_pgm etc were created

# %%
train=pd.read_csv("train1.csv",index_col=0)
train.reset_index(drop=True,inplace=True)

# %%
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175261  train-126324                            Cricket:3787,Reality:57
# 175262  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175263  train-126326                               Drama:25428,Family:7
# 175264  train-126329                              Drama:50749,Romance:9
# 175265  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train.drop(train[train['ID']=='train-157864'].index,inplace=True)
train.drop(train[train['ID']=='train-179191'].index,inplace=True)

# %%
train.reset_index(drop=True,inplace=True)

# %%
train.shape
# Out:
# (175264, 7)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175264 entries, 0 to 175263
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       175264 non-null  object
#  1   genres   175264 non-null  object
#  2   titles   175239 non-null  object
#  3   cities   175264 non-null  object
#  4   segment  175264 non-null  object
#  5   dow      175264 non-null  object
#  6   tod      175264 non-null  object
# dtypes: object(7)
# memory usage: 9.4+ MB

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'tod'].split(","))
    z=[]
    k=[]
    for i in range(0, y):
        x=train.loc[j,'tod'].split(",")[i].split(":")
        z.append(int(x[1]))
        k.append(int(x[0]))

    train.loc[j,'prime_time']=k[z.index(max(z))] 
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175259  train-126324                            Cricket:3787,Reality:57
# 175260  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175261  train-126326                               Drama:25428,Family:7
# 175262  train-126329                              Drama:50749,Romance:9
# 175263  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train.drop(train[train['ID']=='train-131835'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-120708'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-133094'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-189071'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-69894'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-66840'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-31795'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-148920'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-65217'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-57318'].index,inplace=True)
train.drop(train[train['ID']=='train-57606'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'dow'].split(","))
    z=[]
    k=[]
    for i in range(0, y):
        x=train.loc[j,'dow'].split(",")[i].split(":")
        z.append(int(x[1]))
        k.append(int(x[0]))

    train.loc[j,'prime_day']=k[z.index(max(z))]  
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175248  train-126324                            Cricket:3787,Reality:57
# 175249  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175250  train-126326                               Drama:25428,Family:7
# 175251  train-126329                              Drama:50749,Romance:9
# 175252  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'genres'].split(","))
    z=[]
    k=[]
    for i in range(0, y):
        x=train.loc[j,'genres'].split(",")[i].split(":")
        z.append(int(x[1]))
        k.append((x[0]))

    train.loc[j,'prefered_genre']=k[z.index(max(z))]  
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175248  train-126324                            Cricket:3787,Reality:57
# 175249  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175250  train-126326                               Drama:25428,Family:7
# 175251  train-126329                              Drama:50749,Romance:9
# 175252  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train['prefered_genre'].value_counts()
# Out:
# Cricket         67154
# Drama           29464
# Romance         19059
# TalkShow        11880
# Family          10155
# Comedy           8587
# Reality          5991
# Action           5747
# Crime            4700
# Mythology        3418
# LiveTV           3021
# Thriller         2267
# Awards            815
# Football          802
# Kids              519
# Horror            502
# Teen              260
# Wildlife          241
# Travel            196
# Science           128
# Badminton         128
# Sport             127
# Documentary        50
# Kabaddi            13
# Hockey             11
# Formula1           10
# Table Tennis        2
# Athletics           2
# Tennis              2
# NA                  1
# Boxing              1
# Name: prefered_genre, dtype: int64

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'genres'].split(","))
    z=[]
    k=[]
    a=0
    for i in range(0, y):
        x=train.loc[j,'genres'].split(",")[i].split(":")
        z.append(int(x[1]))
        a=a+int(x[1])
        k.append((x[0]))

    train.loc[j,'%time_prefered_genre']=((max(z))/a)*100
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175248  train-126324                            Cricket:3787,Reality:57
# 175249  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175250  train-126326                               Drama:25428,Family:7
# 175251  train-126329                              Drama:50749,Romance:9
# 175252  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
for j in range(0,len(train)):
        train.loc[j,'no_place_presence']=len(train.loc[j,'cities'].split(","))
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175248  train-126324                            Cricket:3787,Reality:57
# 175249  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175250  train-126326                               Drama:25428,Family:7
# 175251  train-126329                              Drama:50749,Romance:9
# 175252  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'cities'].split(","))
    z=[]
    k=[]
    a=0
    for i in range(0, y):
        x=train.loc[j,'cities'].split(",")[i].split(":")
        z.append(int(x[1]))
        a=a+int(x[1])
        k.append((x[0]))

    train.loc[j,'%watched_base_loc']=((max(z))/a)*100
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175248  train-126324                            Cricket:3787,Reality:57
# 175249  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175250  train-126326                               Drama:25428,Family:7
# 175251  train-126329                              Drama:50749,Romance:9
# 175252  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train.drop(train[train['titles'].isnull()].index,inplace=True)

# %%
train.reset_index(drop=True,inplace=True)

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'titles'].split(","))
    z=[]
    k=[]
    for i in range(0, y):
        x=train.loc[j,'titles'].split(",")[i].rsplit(":",1)
        z.append(int(x[1]))
        k.append((x[0]))

    train.loc[j,'most_watched_pgm']=k[z.index(max(z))]  
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175223  train-126324                            Cricket:3787,Reality:57
# 175224  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175225  train-126326                               Drama:25428,Family:7
# 175226  train-126329                              Drama:50749,Romance:9
# 175227  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train.drop(train[train['ID']=='train-56206'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-90125'].index,inplace=True)
train.drop(train[train['ID']=='train-65161'].index,inplace=True)
train.drop(train[train['ID']=='train-40919'].index,inplace=True)
train.drop(train[train['ID']=='train-15083'].index,inplace=True)
train.drop(train[train['ID']=='train-86017'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-108696'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
train.drop(train[train['ID']=='train-119600'].index,inplace=True)
train.reset_index(drop=True,inplace=True)

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'titles'].split(","))
    z=[]
    k=[]
    a=0
    for i in range(0, y):
        x=train.loc[j,'titles'].split(",")[i].rsplit(":",1)
        z.append(int(x[1]))
        a=a+int(x[1])
        #k.append((x[0]))
    train.loc[j,'%watched_fav_pgm']=((max(z))/a)*100
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175215  train-126324                            Cricket:3787,Reality:57
# 175216  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175217  train-126326                               Drama:25428,Family:7
# 175218  train-126329                              Drama:50749,Romance:9
# 175219  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
for j in range(0,len(train)):
        train.loc[j,'no_pgm_watched']=len(train.loc[j,'titles'].split(","))
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175215  train-126324                            Cricket:3787,Reality:57
# 175216  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175217  train-126326                               Drama:25428,Family:7
# 175218  train-126329                              Drama:50749,Romance:9
# 175219  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'tod'].split(","))
    z=[]
    k=[]
    a=0
    for i in range(0, y):
        x=train.loc[j,'tod'].split(",")[i].split(":")
        a=a+int(x[1])
        #z.append(int(x[1]))
        #k.append(int(x[0]))

    train.loc[j,'total_watch_time']=a 
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175215  train-126324                            Cricket:3787,Reality:57
# 175216  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175217  train-126326                               Drama:25428,Family:7
# 175218  train-126329                              Drama:50749,Romance:9
# 175219  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train['gen']=train['genres']
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175215  train-126324                            Cricket:3787,Reality:57
# 175216  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175217  train-126326                               Drama:25428,Family:7
# 175218  train-126329                              Drama:50749,Romance:9
# 175219  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train['gen']=train['gen'].str.replace('Badminton','Sport')
train['gen']=train['gen'].str.replace('Football','Sport')
train['gen']=train['gen'].str.replace('Kabaddi','Sport')
train['gen']=train['gen'].str.replace('Hockey','Sport')
train['gen']=train['gen'].str.replace('Formula1','Sport')
train['gen']=train['gen'].str.replace('Table Tennis','Sport')
train['gen']=train['gen'].str.replace('Tennis','Sport')
train['gen']=train['gen'].str.replace('Athletics','Sport')
train['gen']=train['gen'].str.replace('IndiaVsSa','Sport')
train['gen']=train['gen'].str.replace('Swimming','Sport')
train['gen']=train['gen'].str.replace('FormulaE','Sport')
train['gen']=train['gen'].str.replace('Boxing','Sport')
train['gen']=train['gen'].str.replace('Volleyball','Sport')
train['gen']=train['gen'].str.replace('Documentary','Others')
train['gen']=train['gen'].str.replace('NA','Others')
train['gen']=train['gen'].str.replace('Science','Others')
train['gen']=train['gen'].str.replace('Travel','Others')
train['gen']=train['gen'].str.replace('Wildlife','Others')
train['gen']=train['gen'].str.replace('Teen','Kids')
train['gen']=train['gen'].str.replace('Awards','Reality')
train['gen']=train['gen'].str.replace('Horror','Thriller')

# %%
for j in range(0,len(train)):
    y= len(train.loc[j,'gen'].split(","))
    z=[]
    k=[]
    a=0
    for i in range(0, y):
        x=train.loc[j,'gen'].split(",")[i].split(":")
        z.append(int(x[1]))
        k.append((x[0]))
        a=a+int(x[1])

    for i in range(0,len(k)):
        train.loc[j,k[i]]=(z[i]/a)*100  
train
# Out:
#                   ID                                             genres  \
# 0       train-121672                   Drama:6,Cricket:3469,Wildlife:79
# 1       train-121673  Drama:48949,Family:9927,Crime:1901,Romance:165...
# 2       train-121670  Cricket:5715,Family:2777,Drama:20873,LiveTV:4,...
# 3       train-121671                  Romance:77,Drama:122,Cricket:3883
# 4       train-121676                                      TalkShow:8529
# ...              ...                                                ...
# 175215  train-126324                            Cricket:3787,Reality:57
# 175216  train-126327                  Cricket:5060,Awards:21,Crime:1872
# 175217  train-126326                               Drama:25428,Family:7
# 175218  train-126329                              Drama:50749,Romance:9
# 175219  train-126328  Cricket:17417,Reality:14947,Drama:14565,LiveTV...
#
#                                                    titles  \
# ...

# %%
train.isnull().sum()
# Out:
# ID                           0
# genres                       0
# titles                       0
# cities                       0
# segment                      0
# dow                          0
# tod                          0
# prime_time                   0
# prime_day                    0
# prefered_genre               0
# gen                          0
# Drama                    84455
# Cricket                  66832
# Others                  166493
# Family                  134505
# Crime                   153980
# Romance                 108795
# Action                  141725
# Comedy                  131518
# LiveTV                  148146
# TalkShow                128141
# Reality                 114650
# Thriller                148976
# Sport                   156093
# Kids                    168727
# Mythology               163723
# %time_prefered_genre         0
# no_place_presence            0
# %watched_base_loc            0
# most_watched_pgm             0
# ...

# %%
train.to_csv("final_for_cluster.csv")
